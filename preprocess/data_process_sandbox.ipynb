# %% [markdown]
# # Data Preprocessing Sandbox
# Author: Gurpreet Singh
# Date: 5/7/2025
#
# Sandbox notebook for validating data preprocessing functionality.

# %%
from data_process import get_dataloaders

train_loader, val_loader, test_loader = get_dataloaders()
# Out:
# Num Augmentations to compute: 2350
# Ships padded images: 3000
# Num Augmentations to compute: 350
# Ships non-padded images: 3000
# Train Set Size: 6000
# Test Set Size: 500
# Val Set Size: 200

# %%
from torchvision.transforms import v2

image = next(iter(train_loader))[0]
image_PIL = v2.ToPILImage()(image[0])

import matplotlib.pyplot as plt

plt.imshow(image_PIL)
